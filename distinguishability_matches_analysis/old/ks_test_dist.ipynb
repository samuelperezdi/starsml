# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# # Difference in Distributions of First- and Second-Best Matches

# %% [markdown]
# ## Load Data
# New Data: https://drive.google.com/drive/folders/11rqjfphE7gSC_LsUxEEVe149njpQpt01

# %%
first_match = pd.read_csv('/Users/joshuaingram/Main/Projects/starsml/data/new/most_probable_new.csv')
second_match= pd.read_csv('/Users/joshuaingram/Main/Projects/starsml/data/new/second_new.csv')

# %%
first_match.source_id
# Out:
# 0         2738296192437006848
# 1          429950213735495552
# 2          429950213732833920
# 3         4923631765174494720
# 4          429950071988478720
#                  ...
# 119870    2874986752152587008
# 119871    2012805194581149312
# 119872    2874987130109709312
# 119873    2738295883200826880
# 119874    2012805465146791424
# Name: source_id, Length: 119875, dtype: int64

# %%
first_match.chandra_source_id
# Out:
# 0         2CXO J000000.0+004331
# 1         2CXO J000001.4+623148
# 2         2CXO J000002.9+623156
# 3         2CXO J000004.5-552604
# 4         2CXO J000005.3+623028
#                   ...
# 119870    2CXO J235956.6+325400
# 119871    2CXO J235957.5+622211
# 119872    2CXO J235957.9+325403
# 119873    2CXO J235958.8+004206
# 119874    2CXO J235959.8+622403
# Name: chandra_source_id, Length: 119875, dtype: object

# %%
first_match.columns
# Out:
# Index(['Unnamed: 0', 'chandra_source_id', 'chandra_ra', 'chandra_dec', 'name',
#        'err_ellipse_r0', 'err_ellipse_r1', 'err_ellipse_ang', 'significance',
#        'likelihood_class', 'conf_flag', 'sat_src_flag', 'streak_src_flag',
#        'flux_aper_b', 'flux_aper_lolim_b', 'flux_aper_hilim_b', 'flux_aper_w',
#        'flux_aper_lolim_w', 'flux_aper_hilim_w', 'flux_aper_avg_b',
#        'flux_aper_avg_lolim_b', 'flux_aper_avg_hilim_b', 'flux_aper_avg_w',
#        'flux_aper_avg_lolim_w', 'flux_aper_avg_hilim_w', 'var_inter_prob_b',
#        'var_inter_prob_h', 'var_inter_prob_m', 'var_inter_prob_s',
#        'var_intra_prob_b', 'var_intra_prob_h', 'var_intra_prob_m',
#        'var_intra_prob_s', 'hard_hs', 'hard_hm', 'hard_ms', 'min_theta_mean',
#        'nway_separation', 'dist_bayesfactor', 'dist_post', 'p_single', 'p_any',
#        'p_i', 'match_flag', 'source_id', 'ra', 'dec', 'parallax',
#        'parallax_error', 'parallax_over_error', 'pmra', 'pmdec', 'ruwe',
#        'phot_g_mean_flux', 'phot_g_mean_flux_error',
#        'phot_g_mean_flux_over_error', 'phot_g_mean_mag', 'phot_bp_mean_flux',
#        'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error',
#        'phot_bp_mean_mag', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error',
#        'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'bp_rp', 'bp_g',
#        'g_rp', 'radial_velocity', 'phot_variable_flag', 'dist_arcsec'],
#       dtype='object')

# %%
plt.hist(first_match['dist_arcsec'], bins=100, alpha=0.5, label='first_match')
plt.hist(second_match['dist_arcsec'], bins=100, alpha=0.5, label='second_match')
plt.show()

# %% [markdown]
# # Analysis: No Separation Filtering or Off-Axis Filtering

# %% [markdown]
# ## Colors

# %%
# bp_rp
# first best
sample1 = first_match['bp_rp']
# second best
sample2 = second_match['bp_rp']

# ks test
ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.08666527632950993, pvalue=0.0, statistic_location=6.908633, statistic_sign=1)

# %%
# bp_g
# first best
sample1 = first_match['bp_g']
# second best
sample2 = second_match['bp_g']

# ks test
ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.08640667361835241, pvalue=0.0, statistic_location=5.1906586, statistic_sign=1)

# %%
# g_rp
# first best
sample1 = first_match['g_rp']
# second best
sample2 = second_match['g_rp']

# ks test
ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.10148905109489048, pvalue=0.0, statistic_location=1.4907293, statistic_sign=1)

# %% [markdown]
# ## Magnitudes

# %%
# phot_g_mean_mag
# first best
sample1 = first_match['phot_g_mean_mag']
# second best
sample2 = second_match['phot_g_mean_mag']

# ks test
ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.13371428571428573, pvalue=0.0, statistic_location=18.720013, statistic_sign=1)

# %%
# phot_bp_mean_mag
# first best
sample1 = first_match['phot_bp_mean_mag']
# second best
sample2 = second_match['phot_bp_mean_mag']

ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.12519708029197085, pvalue=0.0, statistic_location=19.83087, statistic_sign=1)

# %%
# phot_rp_mean_mag
# first best
sample1 = first_match['phot_rp_mean_mag']
# second best
sample2 = second_match['phot_rp_mean_mag']

# ks test
ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.1489718456725756, pvalue=0.0, statistic_location=17.69413, statistic_sign=1)

# %% [markdown]
# ## Fluxes

# %%
# phot_g_mean_flux
# first best
sample1 = first_match['phot_g_mean_flux']
# second best
sample2 = second_match['phot_g_mean_flux']

# ks test
ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.13071115745568307, pvalue=0.0, statistic_location=612.2373069792916, statistic_sign=-1)

# %%
# phot_bp_mean_flux
# first best
sample1 = first_match['phot_bp_mean_flux']
# second best
sample2 = second_match['phot_bp_mean_flux']

# ks test
ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.08639833159541188, pvalue=0.0, statistic_location=546428066.1702335, statistic_sign=1)

# %%
# phot_rp_mean_flux
# first best
sample1 = first_match['phot_rp_mean_flux']
# second best
sample2 = second_match['phot_rp_mean_flux']

# ks test
ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.08090093847758084, pvalue=0.0, statistic_location=406803723.3031809, statistic_sign=1)

# %% [markdown]
# ## Radial Velocity

# %%
# radial_velocity
# first best
sample1 = first_match['radial_velocity']
# second best
sample2 = second_match['radial_velocity']

# ks test
ks_test = stats.ks_2samp(sample1, sample2)
print(ks_test)
# Out:
# KstestResult(statistic=0.04797497393117831, pvalue=2.5211337277175745e-120, statistic_location=425.69962, statistic_sign=1)

# %% [markdown]
# # Analysis: Separation Filtering

# %%
def ks_test_filter(data1, data2, column, filter_column, filter_level, filter_count = "second", unique_id = "chandra_source_id"):

    if filter_count == "second":
        data2 = data2[data2[filter_column] < filter_level]
        data1 = data1[data1[unique_id].isin(data2[unique_id])]
    elif filter_count == "first":
        data1 = data1[data1[filter_column] < filter_level]
        data2 = data2[data2[unique_id].isin(data1[unique_id])]
    elif filter_count == "both":
        data1 = data1[data1[filter_column] < filter_level]
        data2 = data2[data2[filter_column] < filter_level]
        data1 = data1[data1[unique_id].isin(data2[unique_id])]
        data2 = data2[data2[unique_id].isin(data1[unique_id])]
    else:
        print("filter_count must be 'first', 'second', or 'both'")
        return
    
    sample1 = data1[column]
    sample2 = data2[column]

    # ks test
    ks_test = stats.ks_2samp(sample1, sample2)

    return ks_test

# %% [markdown]
# ## Magnitudes

# %%
### do filtering on the first best match
# do bins instead of a single value
# get the distribution of the corresponding (leftover) second best matches... (only sources not filtered out for both first and second best matches)

# %%
# phot_g_mean_mag
# FILTER BY FIRST BEST
column = "phot_g_mean_mag"
filter_column = "dist_arcsec"
filter_level = 5 # in arcsec
filter_count = "second"

levels = []
ks_tests_pvals = []

for level in np.arange(0.1, 10, 0.01):
    ks_test = ks_test_filter(first_match, second_match, column, filter_column, filter_level = level, filter_count = "first") # change here

    levels.append(level)
    ks_tests_pvals.append(ks_test.pvalue)
# Out:
# 7391
# 8470
# 9601
# 10737
# 11870
# 12970
# 14132
# 15189
# 16354
# 17531
# 18739
# 19894
# 20944
# 22055
# 23024
# 23969
# 24947
# 25870
# 26857
# 27780
# 28670
# 29511
# 30399
# 31220
# 31982
# 32784
# 33516
# 34194
# 34907
# 35585
# 36235
# 36879
# 37533
# 38130
# 38742
# 39322
# 39924
# 40469
# 41042
# 41552
# 42057
# 42570
# 43070
# 43512
# 43964
# 44398
# 44858
# 45283
# 45700
# 46113
# 46519
# 46913
# 47312
# 47677
# 48063
# 48455
# 48833
# 49231
# 49543
# 49924
# 50307
# 50613
# 50932
# 51275
# 51563
# 51882
# 52189
# 52471
# 52793
# 53086
# 53351
# 53661
# 53958
# 54247
# 54537
# 54829
# 55105
# 55383
# 55680
# 55951
# 56209
# 56456
# 56704
# 56968
# 57210
# 57447
# 57696
# 57936
# 58148
# 58359
# 58581
# 58779
# 59023
# 59254
# 59478
# 59692
# 59922
# 60140
# 60368
# 60604
# 60832
# 61049
# 61256
# 61457
# 61667
# 61854
# 62057
# 62254
# 62466
# 62665
# 62840
# 63047
# 63265
# 63481
# 63674
plt.show()

# %%
# find the level where the p-value is 0.05
for i in range(len(ks_tests_pvals)):
    if ks_tests_pvals[i] < 0.05:
        print("p-value is less than 0.05 at max separation of " + str(levels[i]) + " arcsec")
        break

# %%
# phot_g_mean_mag
# FILTER BY SECOND BEST
column = "phot_g_mean_mag"
filter_column = "dist_arcsec"
filter_level = 5 # in arcsec
filter_count = "second"

levels = []
ks_tests_pvals = []

for level in np.arange(0.1, 5, 0.01):
    ks_test = ks_test_filter(first_match, second_match, column, filter_column, filter_level = level, filter_count = "second") # change here

    levels.append(level)
    ks_tests_pvals.append(ks_test.pvalue)
# Out:
# /var/folders/k3/6x6tz2rj1qb4727bvm_ytpqc0000gn/T/ipykernel_85715/2387865525.py:22: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   ks_test = stats.ks_2samp(sample1, sample2)

# %%
plt.plot(levels, ks_tests_pvals)
plt.xlabel("Max separation (arcsec) for first best match")
plt.ylabel("KS test p-value")
plt.title("G MEAN MAG: p-value vs Max separation (first best match)")
plt.show()

# %%
# find the level where the p-value is 0.05
for i in range(len(ks_tests_pvals)):
    if ks_tests_pvals[i] < 0.05:
        print("p-value is less than 0.05 at max separation of " + str(levels[i]) + " arcsec")
        break
# Out:
# p-value is less than 0.05 at max separation of 0.6099999999999998 arcsec

# %%
# phot_bp_mean_mag
# FILTER BY FIRST BEST
column = "phot_bp_mean_mag"
filter_column = "dist_arcsec"
filter_level = 5 # in arcsec
filter_count = "second"

levels = []
ks_tests_pvals = []

for level in np.arange(0.1, 10, 0.01):
    ks_test = ks_test_filter(first_match, second_match, column, filter_column, filter_level = level, filter_count = "first")

    levels.append(level)
    ks_tests_pvals.append(ks_test.pvalue)
# Out:
# 7391
# 8470
# 9601
# 10737
# 11870
# 12970
# 14132
# 15189
# 16354
# 17531
# 18739
# 19894
# 20944
# 22055
# 23024
# 23969
# 24947
# 25870
# 26857
# 27780
# 28670
# 29511
# 30399
# 31220
# 31982
# 32784
# 33516
# 34194
# 34907
# 35585
# 36235
# 36879
# 37533
# 38130
# 38742
# 39322
# 39924
# 40469
# 41042
# 41552
# 42057
# 42570
# 43070
# 43512
# 43964
# 44398
# 44858
# 45283
# 45700
# 46113
# 46519
# 46913
# 47312
# 47677
# 48063
# 48455
# 48833
# 49231
# 49543
# 49924
# 50307
# 50613
# 50932
# 51275
# 51563
# 51882
# 52189
# 52471
# 52793
# 53086
# 53351
# 53661
# 53958
# 54247
# 54537
# 54829
# 55105
# 55383
# 55680
# 55951
# 56209
# 56456
# 56704
# 56968
# 57210
# 57447
# 57696
# 57936
# 58148
# 58359
# 58581
# 58779
# 59023
# 59254
# 59478
# 59692
# 59922
# 60140
# 60368
# 60604
# 60832
# 61049
# 61256
# 61457
# 61667
# 61854
# 62057
# 62254
# 62466
# 62665
# 62840
# 63047
# 63265
# 63481
# 63674
# 63846
# 64041
# 64215
# 64418
# 64621
# 64793
# 64976
# 65174
# 65346
# 65535
# 65721
# 65921
# 66104
        print("p-value is less than 0.05 at max separation of " + str(levels[i]) + " arcsec")
        break
# Out:
# p-value is less than 0.05 at max separation of 0.1 arcsec

# %%
# phot_bp_mean_mag
# FILTER BY SECOND BEST
column = "phot_bp_mean_mag"
filter_column = "dist_arcsec"
filter_level = 5 # in arcsec
filter_count = "second"

levels = []
ks_tests_pvals = []

for level in np.arange(0.1, 5, 0.01):
    ks_test = ks_test_filter(first_match, second_match, column, filter_column, filter_level = level, filter_count = "second")

    levels.append(level)
    ks_tests_pvals.append(ks_test.pvalue)
# Out:
# /var/folders/k3/6x6tz2rj1qb4727bvm_ytpqc0000gn/T/ipykernel_85715/2387865525.py:22: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   ks_test = stats.ks_2samp(sample1, sample2)

# %%
plt.plot(levels, ks_tests_pvals)
plt.xlabel("Max separation (arcsec) for second best match")
plt.ylabel("KS test p-value")
plt.title("BP MEAN MAG: p-value vs Max separation (second best match)")
plt.show()

# %%
# find the level where the p-value is 0.05
for i in range(len(ks_tests_pvals)):
    if ks_tests_pvals[i] < 0.05:
        print("p-value is less than 0.05 at max separation of " + str(levels[i]) + " arcsec")
        break
# Out:
# p-value is less than 0.05 at max separation of 0.5399999999999998 arcsec

# %%
# phot_rp_mean_mag
# FILTER BY FIRST BEST
column = "phot_rp_mean_mag"
filter_column = "dist_arcsec"
filter_level = 5 # in arcsec
filter_count = "second"

levels = []
ks_tests_pvals = []

for level in np.arange(0.1, 10, 0.01):
    ks_test = ks_test_filter(first_match, second_match, column, filter_column, filter_level = level, filter_count = "first")

    levels.append(level)
    ks_tests_pvals.append(ks_test.pvalue)

# %%
plt.plot(levels, ks_tests_pvals)
plt.xlabel("Max separation (arcsec) for first best match")
plt.ylabel("KS test p-value")
plt.title("p-value vs Max separation (first best match)")
plt.show()

# %%
# find the level where the p-value is 0.05
for i in range(len(ks_tests_pvals)):
    if ks_tests_pvals[i] < 0.05:
        print("p-value is less than 0.05 at max separation of " + str(levels[i]) + " arcsec")
        break
# Out:
# p-value is less than 0.05 at max separation of 0.1 arcsec

# %%
# phot_rp_mean_mag
# FILTER BY SECOND BEST
column = "phot_rp_mean_mag"
filter_column = "dist_arcsec"
filter_level = 5 # in arcsec
filter_count = "second"

levels = []
ks_tests_pvals = []

for level in np.arange(0.1, 5, 0.01):
    ks_test = ks_test_filter(first_match, second_match, column, filter_column, filter_level = level, filter_count = "second")

    levels.append(level)
    ks_tests_pvals.append(ks_test.pvalue)
# Out:
# /var/folders/k3/6x6tz2rj1qb4727bvm_ytpqc0000gn/T/ipykernel_85715/2387865525.py:22: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   ks_test = stats.ks_2samp(sample1, sample2)

# %%
plt.plot(levels, ks_tests_pvals)
plt.xlabel("Max separation (arcsec) for second best match")
plt.ylabel("KS test p-value")
plt.title("RP MEAN MAG: p-value vs Max separation (second best match)")
plt.show()

# %%
# find the level where the p-value is 0.05
for i in range(len(ks_tests_pvals)):
    if ks_tests_pvals[i] < 0.05:
        print("p-value is less than 0.05 at max separation of " + str(levels[i]) + " arcsec")
        break
# Out:
# p-value is less than 0.05 at max separation of 0.5399999999999998 arcsec

# %% [markdown]
# # Analysis: Off-Axis Filtering

# %% [markdown]
# # 0-3, 3-5, >5 arcmin
# min_theta_means

# %%
# phot_g_mean_mag
# FILTER BY SECOND BEST
column = "phot_g_mean_mag"
filter_column = "min_theta_mean"
filter_level = 5 # in arcsec
filter_count = "second"

levels = []
ks_tests_pvals = []

for level in np.arange(0.1, 5, 0.01):
    ks_test = ks_test_filter(first_match, second_match, column, filter_column, filter_level = level, filter_count = "second")

    levels.append(level)
    ks_tests_pvals.append(ks_test.pvalue)

# %%
plt.plot(levels, ks_tests_pvals)
plt.xlabel("Max Off-Axis Angle for second best match")
plt.ylabel("KS test p-value")
plt.title("G MEAN MAG: p-value vs Max Off-Axis Angle (second best match)")
plt.show()

# %%
# find the level where the p-value is 0.05
for i in range(len(ks_tests_pvals)):
    if ks_tests_pvals[i] < 0.05:
        print("p-value is less than 0.05 at max off-axis angle of " + str(levels[i]) + " arcsec")
        break
# Out:
# p-value is less than 0.05 at max off-axis angle of 0.13 arcsec

# %%
# phot_bp_mean_mag
# FILTER BY SECOND BEST
column = "phot_bp_mean_mag"
filter_column = "min_theta_mean"
filter_level = 5 # in arcsec
filter_count = "second"

levels = []
ks_tests_pvals = []

for level in np.arange(0.1, 5, 0.01):
    ks_test = ks_test_filter(first_match, second_match, column, filter_column, filter_level = level, filter_count = "second")

    levels.append(level)
    ks_tests_pvals.append(ks_test.pvalue)

# %%
plt.plot(levels, ks_tests_pvals)
plt.xlabel("Max Off-Axis Angle for second best match")
plt.ylabel("KS test p-value")
plt.title("BP MEAN MAG: p-value vs Max Off-Axis Angle (second best match)")
plt.show()

# %%
# find the level where the p-value is 0.05
for i in range(len(ks_tests_pvals)):
    if ks_tests_pvals[i] < 0.05:
        print("p-value is less than 0.05 at max off-axis angle of " + str(levels[i]) + " arcsec")
        break
# Out:
# p-value is less than 0.05 at max off-axis angle of 0.1 arcsec

# %%
# phot_rp_mean_mag
# FILTER BY SECOND BEST
column = "phot_rp_mean_mag"
filter_column = "min_theta_mean"
filter_level = 5 # in arcsec
filter_count = "second"

levels = []
ks_tests_pvals = []

for level in np.arange(0.1, 5, 0.01):
    ks_test = ks_test_filter(first_match, second_match, column, filter_column, filter_level = level, filter_count = "second")

    levels.append(level)
    ks_tests_pvals.append(ks_test.pvalue)

# %%
plt.plot(levels, ks_tests_pvals)
plt.xlabel("Max Off-Axis Angle for second best match")
plt.ylabel("KS test p-value")
plt.title("RP MEAN MAG: p-value vs Max Off-Axis Angle (second best match)")
plt.show()

# %%
# find the level where the p-value is 0.05
for i in range(len(ks_tests_pvals)):
    if ks_tests_pvals[i] < 0.05:
        print("p-value is less than 0.05 at max off-axis angle of " + str(levels[i]) + " arcsec")
        break
# Out:
# p-value is less than 0.05 at max off-axis angle of 0.1 arcsec
